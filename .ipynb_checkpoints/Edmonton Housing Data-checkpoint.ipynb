# %% [markdown]
# # Edmonton Housing Data Analysis: A Saga

# %% [markdown]
# ## By Paul Saunders

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('whitegrid')
import rise

# %%
housing = pd.read_csv('../../Data/Property_Assessment_Data__Current_Calendar_Year_.csv')
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# Let's take a quick look at what we're working with.

# %%
housing.head()
# Out:
#    Account Number Suite  House Number               Street Name  \
# 0        10202374   NaN         455.0         MCCONACHIE WAY NW
# 1         9969312   NaN       15519.0             103 STREET NW
# 2        10030551    11        1780.0  GLASTONBURY BOULEVARD NW
# 3         1263045   306       14916.0              26 STREET NW
# 4        10176917   NaN       16923.0              71 STREET NW
#
#    Assessed Value Assessment Class  Neighbourhood ID    Neighbourhood    Ward  \
# 0          381500      Residential            2521.0  MCCONACHIE AREA  Ward 3
# 1          463500      Residential            3040.0        BEAUMARIS  Ward 2
# 2          271000      Residential            4720.0      GLASTONBURY  Ward 1
# 3           69500      Residential            2280.0           FRASER  Ward 4
# 4          553500      Residential            2700.0         SCHONSEE  Ward 3
#
#   Garage   Latitude   Longitude
# 0      Y  53.630842 -113.428512
# 1      Y  53.616836 -113.500368
# ...

# %%
# Replacing duplicate, don't worry abt it
housing.loc[37700] = housing.loc[49074]

# %%
housing['Ward'] = housing['Ward'].apply(lambda ward: int(ward[5:]))

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400916 entries, 0 to 400915
# Data columns (total 12 columns):
# Account Number      400916 non-null int64
# Suite               79397 non-null object
# House Number        358129 non-null float64
# Street Name         358129 non-null object
# Assessed Value      400916 non-null int64
# Assessment Class    400916 non-null object
# Neighbourhood ID    400916 non-null float64
# Neighbourhood       400916 non-null object
# Ward                400916 non-null int64
# Garage              400916 non-null object
# Latitude            400916 non-null float64
# Longitude           400916 non-null float64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 36.7+ MB

# %%
housing.describe()
# Out:
#        Account Number   House Number  Assessed Value  Neighbourhood ID  \
# count    4.009160e+05  358129.000000    4.009160e+05     400916.000000
# mean     7.644137e+06    7801.138076    4.656803e+05       4248.527145
# std      3.267651e+06    5379.167705    3.683814e+06       1765.558692
# min      1.001007e+06       1.000000    0.000000e+00       1010.000000
# 25%      4.243992e+06    2729.000000    1.770000e+05       2600.000000
# 50%      9.940566e+06    8307.000000    3.235000e+05       4500.000000
# 75%      1.013153e+07   11450.000000    4.260000e+05       5576.000000
# max      1.094012e+07   51175.000000    1.338810e+09       8888.000000
#
#                 Ward       Latitude      Longitude
# count  400916.000000  400916.000000  400916.000000
# mean        6.216025      53.520081    -113.511479
# std         3.766180       0.067231       0.081662
# min         1.000000      53.338595    -113.713318
# 25%         2.000000      53.461483    -113.566806
# ...

# %%
# Get temporary labels to make the heatmap more descriptive
from sklearn.preprocessing import LabelEncoder

housingCorr = housing.copy()

cats = ['Street Name', 'Assessment Class', 'Neighbourhood', 'Garage']
encoder = LabelEncoder()

for cat in cats:
    housingCorr[cat].mask(housingCorr[cat].isna(), 'null', inplace=True)
    col = cat + '_label'
    housingCorr[col] = encoder.fit_transform(housingCorr[cat])

plt.figure(figsize=(12, 9))
sns.set(font_scale=1.2)
sns.heatmap(housingCorr.corr())

# %% [markdown]
# Notice that all of the columns used in this heat map are either unique to each and every house or are so common that no significant difference can be obtained. The latitude and longitude should be extremely good at predicting, but since all coords are in Edmonton the difference between them is insignificant

# %%
houseX = housing.drop('Assessed Value', axis=1)

# %%
houseY = housing['Assessed Value']

# %%
houseX.head()
# Out:
#    Account Number Suite  House Number               Street Name  \
# 0        10202374   NaN         455.0         MCCONACHIE WAY NW
# 1         9969312   NaN       15519.0             103 STREET NW
# 2        10030551    11        1780.0  GLASTONBURY BOULEVARD NW
# 3         1263045   306       14916.0              26 STREET NW
# 4        10176917   NaN       16923.0              71 STREET NW
#
#   Assessment Class  Neighbourhood ID    Neighbourhood  Ward Garage   Latitude  \
# 0      Residential            2521.0  MCCONACHIE AREA     3      Y  53.630842
# 1      Residential            3040.0        BEAUMARIS     2      Y  53.616836
# 2      Residential            4720.0      GLASTONBURY     1      N  53.501531
# 3      Residential            2280.0           FRASER     4      N  53.611973
# 4      Residential            2700.0         SCHONSEE     3      Y  53.630884
#
#     Longitude
# 0 -113.428512
# 1 -113.500368
# 2 -113.672511
# 3 -113.379481
# 4 -113.450859

# %%
houseX.nunique()
# Out:
# Account Number      400915
# Suite                 2245
# House Number         18443
# Street Name           2845
# Assessment Class         4
# Neighbourhood ID       398
# Neighbourhood          398
# Ward                    12
# Garage                   2
# Latitude            255906
# Longitude           237599
# dtype: int64

# %% [markdown]
# # Preprocessing

# %% [markdown]
# Let's quickly take a look at the percentages of null valuesStandardScaler each column

# %%
houseX.isna().sum()/len(houseX)
# Out:
# Account Number      0.000000
# Suite               0.801961
# House Number        0.106723
# Street Name         0.106723
# Assessment Class    0.000000
# Neighbourhood ID    0.000000
# Neighbourhood       0.000000
# Ward                0.000000
# Garage              0.000000
# Latitude            0.000000
# Longitude           0.000000
# dtype: float64

# %% [markdown]
# Since there is a unique account number for every row, we will drop that field.

# %%
houseX.drop('Account Number', axis=1, inplace=True)

# %% [markdown]
# Suite has a null rate of 80%! Chances are that null values are just houses or stand-alone units, so it is possible that field could have value to it. We will see if we can find a value that does not exist in the 'Suite' column, and initialize all null values to that.

# %%
len(houseX[houseX['Suite'] == 0])
# Out:
# 0

# %%
houseX['Suite'].where(houseX['Suite'].notnull(), 0, inplace=True)

# %%
houseX['Suite'].value_counts()
# Out:
# 0        321519
# 201        1031
# 202         989
# 101         968
# 203         965
#           ...
# 23P           1
# 3215          1
# 304P          1
# 11314         1
# 11316         1
# Name: Suite, Length: 2246, dtype: int64

# %% [markdown]
# Let's take a look at those house #s and street names, as their percentages are exactly the same.

# %%
np.logical_xor(houseX['House Number'].isna(), houseX['Street Name'].isna()).sum()
# Out:
# 0

# %%
np.logical_and(houseX['House Number'].isna(), houseX['Street Name'].isna()).sum()
# Out:
# 42787

# %%
houseX['House Number'].isna().sum()
# Out:
# 42787

# %%
42787 / len(houseX)
# Out:
# 0.10672310409163016

# %% [markdown]
# So every element with a missing house # has a missing street #, and vice versa. Are any of their assessment classes?

# %%
np.logical_and(houseX['Assessment Class'] == 'Residential', houseX['Street Name'].isna()).sum()
# Out:
# 40605

# %%
plt.figure(figsize=(12, 12))
sns.scatterplot(x='Longitude', y='Latitude', hue='Assessment Class', data=houseX[(houseX['Street Name'].isna())])

# %%
plt.figure(figsize=(12, 12))
sns.scatterplot(x='Longitude', y='Latitude', data=houseX)

# %%
houseX.columns
# Out:
# Index(['Suite', 'House Number', 'Street Name', 'Assessment Class',
#        'Neighbourhood ID', 'Neighbourhood', 'Ward', 'Garage', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %% [markdown]
# Normalize and scale latitude, longitude.

# %%
from math import floor, ceil
def returnMantissa(num):
    # Returns the mantissa
    if num > 0:
        integer = floor(num)
    elif num < 0:
        integer = ceil(num)
    else:
        return np.nan
    return num % integer

# %%
houseX['Longitude'] = houseX['Longitude'].apply(lambda x: returnMantissa(x))
houseX['Latitude'] = houseX['Latitude'].apply(lambda x: returnMantissa(x))
housing['Longitude'] = housing['Longitude'].apply(lambda x: returnMantissa(x))
housing['Latitude'] = housing['Latitude'].apply(lambda x: returnMantissa(x))

# %% [markdown]
# Now, we will categorize the data based on a few different attributes: Assessment Class, Ward, Garage.

# %%
for hue in ['Assessment Class', 'Ward', 'Garage']:
    plt.figure(figsize=(10, 10))
    sns.scatterplot(x='Longitude', y='Latitude', hue=hue, data=houseX)
    plt.title('Longitude vs. Latitude: Hue = ' + hue)
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')

# %% [markdown]
# ### Wait, what is that in the middle of Terwillegar Park?

# %%
plt.figure(figsize=(12, 12))
sns.scatterplot(x='Longitude', y='Latitude', 
                data=houseX[((-0.59 > houseX['Longitude']) & (houseX['Longitude'] > -0.64)) & ((0.50 > houseX['Latitude']) & (houseX['Latitude'] > 0.46))])

# %% [markdown]
# Seems to be some sort of house...

# %%
plt.figure(figsize=(12, 12))
sns.scatterplot(x='Longitude', y='Latitude', hue='Garage',
                data=houseX[((-0.59 > houseX['Longitude']) & (houseX['Longitude'] > -0.64)) & ((0.50 > houseX['Latitude']) & (houseX['Latitude'] > 0.46))])

# %% [markdown]
# It doesn't have a garage though.

# %% [markdown]
# If anyone isn't from Edmonton, this is what Terwillegar Park looks like:

# %% [markdown]
# ![Image of Terwillegar Park](https://i.pinimg.com/736x/de/5f/d5/de5fd5ddbf576912a1fba6249f7d30ec.jpg)

# %% [markdown]
# I've been here plenty of times, and I've never seen a house or any type of building in this park.

# %% [markdown]
# Let's take a look at that piece of data specifically.

# %%
houseX[((-0.61 > houseX['Longitude']) & (houseX['Longitude'] > -0.625)) & ((0.485 > houseX['Latitude']) & (houseX['Latitude'] > 0.48))]
# Out:
#        Suite  House Number          Street Name Assessment Class  \
# 184049     0          10.0  RABBIT HILL ROAD NW  Non Residential
#
#         Neighbourhood ID             Neighbourhood  Ward Garage  Latitude  \
# 184049            5380.0  RIVER VALLEY TERWILLEGAR     5      N  0.482798
#
#         Longitude
# 184049  -0.619143

# %% [markdown]
# Looking the house up on google maps...

# %%
from IPython.display import Image
Image(filename='../../../Images/TerwillegarParkGoogleMaps.jpg')

# %% [markdown]
# It seems to be the park itself. On further inspection, it makes sense, as the dataset is for 'properties', not 'houses'

# %% [markdown]
# For the sake of interest, what is the value of Terwillegar Park?

# %%
housing[((-0.61 > housing['Longitude']) & (housing['Longitude'] > -0.625)) & ((0.485 > housing['Latitude']) & (housing['Latitude'] > 0.48))]
# Out:
#         Account Number Suite  House Number          Street Name  \
# 184049         7989510   NaN          10.0  RABBIT HILL ROAD NW
#
#         Assessed Value Assessment Class  Neighbourhood ID  \
# 184049         4271500  Non Residential            5380.0
#
#                    Neighbourhood  Ward Garage  Latitude  Longitude
# 184049  RIVER VALLEY TERWILLEGAR     5      N  0.482798  -0.619143

# %% [markdown]
# If anyone has a spare 4 million lying around, you could purchase Terwillegar Park!

# %% [markdown]
# ## Feature Engineering
# ### Game Plan
# There's not a whole lot of unique information about the houses themselves in the data, so let's see what we can create!

# %%
houseX.columns
# Out:
# Index(['Suite', 'House Number', 'Street Name', 'Assessment Class',
#        'Neighbourhood ID', 'Neighbourhood', 'Ward', 'Garage', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %% [markdown]
# We would think that Latitude and Longitude would directly imply Ward, but let's see if this is really true.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(houseX[['Latitude', 'Longitude']], 
                                                    houseX['Ward'], 
                                                    test_size=0.33, 
                                                    random_state=69,
                                                    stratify=houseX['Ward'])

# %% [markdown]
# We will train a model to use Latitude and Longitude to compute Ward. Using GridSearchCV, we found that the optimal 'C' is 10

# %% [markdown]
# Now, we train

# %%
from sklearn.svm import LinearSVC
svc = LinearSVC(C=10, max_iter=10000)

svc.fit(X_train, y_train)
predictions = svc.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

print(classification_report(y_test, predictions))
print(confusion_matrix(y_test, predictions))
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
#               precision    recall  f1-score   support
#
#            1       0.72      0.97      0.83     16598
#            2       0.65      0.99      0.79     18503
#            3       0.95      0.52      0.67      8653
#            4       0.72      0.88      0.79     10334
#            5       0.00      0.00      0.00      6506
#            6       0.00      0.00      0.00      9623
#            7       0.00      0.00      0.00      2890
#            8       0.54      0.60      0.57     11355
#            9       0.74      0.56      0.64      9981
#           10       0.66      0.82      0.73     14408
#           11       0.69      0.86      0.76     15171
#           12       0.87      0.77      0.82      8281
#
# ...

# %%
set(y_test) - set(predictions)
# Out:
# {5, 7}

# %% [markdown]
# Now, let's see what information is missing in the table, and what can be created using feature engineering

# %%
# Gets percentage of the grouping Column that is 'clas' in column 'col'
def percentOfTotal(grouping, col, clas):
    total = houseX.groupby(grouping)[col].count()
    recs = houseX[houseX[col] == clas].groupby(grouping)[col].count()
    out = (recs / total) * 100
    return out.sort_values(ascending=False)

y1 = houseX['Neighbourhood ID'].unique()
y2 = houseX['Ward'].unique()

# Creates the plots for each Assessment Class for both Neighbourhood ID a
for aIDClass in houseX['Assessment Class'].unique():
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (16, 5))
    x1 = percentOfTotal('Neighbourhood ID', 'Assessment Class', aIDClass)
    x2 = percentOfTotal('Ward', 'Assessment Class', aIDClass)
    sns.scatterplot(x1, y1, ax=ax1)
    sns.scatterplot(x2, y2, ax=ax2)
    plt.title("Assessment Class = " + aIDClass)

# %% [markdown]
# Some quick analysis

# %%
# Neighbourhoods with 100% residential properties
tot = percentOfTotal('Neighbourhood ID', 'Assessment Class', 'Residential')
for houseID in tot[tot == 100].index:
    print(houseX[houseX['Neighbourhood ID'] == houseID]['Neighbourhood'].unique())
# Out:
# ['WESTVIEW VILLAGE']
# ['ANTHONY HENDAY SOUTH BLACKBURNE']

# %%
# Farmland with > 60% residential properties
tot = percentOfTotal('Neighbourhood ID', 'Assessment Class', 'Farmland')
for houseID in tot[tot > 60].index:
    print(houseX[houseX['Neighbourhood ID'] == houseID]['Neighbourhood'].unique())
# Out:
# ['MATTSON']

# %% [markdown]
# From Wikipedia (https://en.wikipedia.org/wiki/Mattson,_Edmonton)
# > Mattson is a future neighbourhood in southeast Edmonton, Alberta, Canada. The neighbourhood was officially named in July 2012 after Norman Mattson, a prominent land surveyor in Alberta
#
# So 'Mattson' is a neighbourhood that hasn't even been remotely developed yet. I'd be interested to see how this neighbourhood has and will change over time

# %%
# Neighbourhoods with > 60% residential properties
tot = percentOfTotal('Neighbourhood ID', 'Assessment Class', 'Non Residential')
totCount = 0
count = 0
for houseID in tot[tot == 100].index:
    string = houseX[houseX['Neighbourhood ID'] == houseID]['Neighbourhood'].unique()
    totCount += 1
    if 'INDUSTRIAL' in string[0]:
        count += 1

print(round(count / totCount, 3))
# Out:
# 0.81

# %% [markdown]
# 81% of all non-residential neighbourhoods in Edmonton have the word 'INDUSTRIAL' in thier name.

# %% [markdown]
# We could add this percentage as a value for each house.
# We could add the average house value for the property's neighbourhood as an attribute
# We could add the

# %%
houseX.head()
# Out:
#   Suite  House Number               Street Name Assessment Class  \
# 0     0         455.0         MCCONACHIE WAY NW      Residential
# 1     0       15519.0             103 STREET NW      Residential
# 2    11        1780.0  GLASTONBURY BOULEVARD NW      Residential
# 3   306       14916.0              26 STREET NW      Residential
# 4     0       16923.0              71 STREET NW      Residential
#
#    Neighbourhood ID    Neighbourhood  Ward Garage  Latitude  Longitude
# 0            2521.0  MCCONACHIE AREA     3      Y  0.630842  -0.428512
# 1            3040.0        BEAUMARIS     2      Y  0.616836  -0.500368
# 2            4720.0      GLASTONBURY     1      N  0.501531  -0.672511
# 3            2280.0           FRASER     4      N  0.611973  -0.379481
# 4            2700.0         SCHONSEE     3      Y  0.630884  -0.450859
